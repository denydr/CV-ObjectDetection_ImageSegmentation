# %% [markdown]
# ## Step 1: Load DAVIS Semantics JSON and Classify Sequences

# %% [markdown]
# #### This code loads davis_semantics.json and separates the sequence into two directiories—one for sequences with a single object and one for sequences with multiple objects

# %% [markdown]
# #### PT.2 Deriving Bounding Boxes: Binary Masks on Grayscaled Single-Object Sequences

# %%
# Checking the graysclae value of the masks to choose the threshold at which the mask should become white
import cv2
import numpy as np
from pathlib import Path

# Define the root folder where your grayscale masks are stored.
# Adjust this path if necessary.
grayscale_dir = Path("output") / "grayscale_single_object_masks"

# Iterate over each sequence folder and then over each image file in those folders.
for sequence_folder in grayscale_dir.iterdir():
    if sequence_folder.is_dir():
        print(f"Sequence: {sequence_folder.name}")
        for img_file in sequence_folder.glob("*.*"):
            # Process only image files with common extensions.
            if img_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                # Load the mask in grayscale.
                mask = cv2.imread(str(img_file), cv2.IMREAD_GRAYSCALE)
                if mask is None:
                    print(f"  Failed to load: {img_file}")
                    continue
                # Find unique pixel values.
                unique_vals = np.unique(mask)
                print(f"  {img_file.name}: {unique_vals}")
# Out:
# Sequence: hike
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: mallard-fly
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00064.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: dance-jump
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: mallard-water
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: cows
#   00091.png: [ 0 38]
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00090.png: [ 0 38]
#   00086.png: [ 0 38]
#   00092.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00093.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00097.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00096.png: [ 0 38]
#   00082.png: [ 0 38]
#   00094.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00095.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00098.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00099.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00101.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00100.png: [ 0 38]
#   00102.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
#   00103.png: [ 0 38]
# Sequence: dance-twirl
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00086.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00082.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: dog
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: lucia
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00064.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: bear
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: boat
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: rollerblade
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
# Sequence: camel
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00086.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00082.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: drift-chicane
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: parkour
#   00091.png: [ 0 38]
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00090.png: [ 0 38]
#   00086.png: [ 0 38]
#   00092.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00093.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00097.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00096.png: [ 0 38]
#   00082.png: [ 0 38]
#   00094.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00095.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00098.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00099.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: bus
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: goat
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00086.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00082.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: breakdance
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00083.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00082.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: car-roundabout
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: soccerball
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
# Sequence: drift-turn
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: breakdance-flare
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: dog-agility
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00023.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
# Sequence: libby
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: drift-straight
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: rhino
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00086.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00082.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: koala
#   00091.png: [ 0 38]
#   00085.png: [ 0 38]
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00084.png: [ 0 38]
#   00090.png: [ 0 38]
#   00086.png: [ 0 38]
#   00092.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00093.png: [ 0 38]
#   00087.png: [ 0 38]
#   00083.png: [ 0 38]
#   00097.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00096.png: [ 0 38]
#   00082.png: [ 0 38]
#   00094.png: [ 0 38]
#   00080.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00081.png: [ 0 38]
#   00095.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00098.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00099.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00089.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
#   00088.png: [ 0 38]
# Sequence: rallye
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: varanus-cage
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00066.png: [ 0 38]
#   00064.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
# Sequence: flamingo
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: car-turn
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]
# Sequence: car-shadow
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
# Sequence: blackswan
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00045.png: [ 0 38]
#   00044.png: [ 0 38]
#   00040.png: [ 0 38]
#   00041.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00049.png: [ 0 38]
#   00048.png: [ 0 38]
# Sequence: elephant
#   00052.png: [ 0 38]
#   00046.png: [ 0 38]
#   00047.png: [ 0 38]
#   00053.png: [ 0 38]
#   00045.png: [ 0 38]
#   00051.png: [ 0 38]
#   00079.png: [ 0 38]
#   00078.png: [ 0 38]
#   00050.png: [ 0 38]
#   00044.png: [ 0 38]
#   00068.png: [ 0 38]
#   00040.png: [ 0 38]
#   00054.png: [ 0 38]
#   00055.png: [ 0 38]
#   00041.png: [ 0 38]
#   00069.png: [ 0 38]
#   00057.png: [ 0 38]
#   00043.png: [ 0 38]
#   00042.png: [ 0 38]
#   00056.png: [ 0 38]
#   00031.png: [ 0 38]
#   00025.png: [ 0 38]
#   00019.png: [ 0 38]
#   00018.png: [ 0 38]
#   00024.png: [ 0 38]
#   00030.png: [ 0 38]
#   00026.png: [ 0 38]
#   00032.png: [ 0 38]
#   00033.png: [ 0 38]
#   00027.png: [ 0 38]
#   00023.png: [ 0 38]
#   00037.png: [ 0 38]
#   00036.png: [ 0 38]
#   00022.png: [ 0 38]
#   00008.png: [ 0 38]
#   00034.png: [ 0 38]
#   00020.png: [ 0 38]
#   00021.png: [ 0 38]
#   00035.png: [ 0 38]
#   00009.png: [ 0 38]
#   00010.png: [ 0 38]
#   00004.png: [ 0 38]
#   00038.png: [ 0 38]
#   00039.png: [ 0 38]
#   00005.png: [ 0 38]
#   00011.png: [ 0 38]
#   00007.png: [ 0 38]
#   00013.png: [ 0 38]
#   00012.png: [ 0 38]
#   00006.png: [ 0 38]
#   00002.png: [ 0 38]
#   00016.png: [ 0 38]
#   00017.png: [ 0 38]
#   00003.png: [ 0 38]
#   00029.png: [ 0 38]
#   00015.png: [ 0 38]
#   00001.png: [ 0 38]
#   00000.png: [ 0 38]
#   00014.png: [ 0 38]
#   00028.png: [ 0 38]
#   00073.png: [ 0 38]
#   00067.png: [ 0 38]
#   00066.png: [ 0 38]
#   00072.png: [ 0 38]
#   00064.png: [ 0 38]
#   00070.png: [ 0 38]
#   00058.png: [ 0 38]
#   00059.png: [ 0 38]
#   00071.png: [ 0 38]
#   00065.png: [ 0 38]
#   00049.png: [ 0 38]
#   00061.png: [ 0 38]
#   00075.png: [ 0 38]
#   00074.png: [ 0 38]
#   00060.png: [ 0 38]
#   00048.png: [ 0 38]
#   00076.png: [ 0 38]
#   00062.png: [ 0 38]
#   00063.png: [ 0 38]
#   00077.png: [ 0 38]

# %%
# Checking the graysclae value of the mask to choose the threshold at which the mask should become white
from pathlib import Path
import cv2

mask_path = Path("output/grayscale_single_object_masks/dog/00000.png")
grayscale_mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
unique_vals = np.unique(grayscale_mask)
print("Unique pixel values in the grayscale mask:", unique_vals)
# Out:
# Unique pixel values in the grayscale mask: [ 0 38]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

def convert_to_binary_mask_otsu(grayscale_mask):
    """
    Applies Otsu's thresholding to a grayscale mask to produce a binary mask.
    """
    # Use Otsu's thresholding: the threshold value is automatically determined.
    ret, binary_mask = cv2.threshold(grayscale_mask, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    print(f"Otsu threshold: {ret}")
    return binary_mask

# Example usage:
mask_path = Path("output/grayscale_single_object_masks/dog/00000.png")
grayscale_mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
binary_mask = convert_to_binary_mask_otsu(grayscale_mask)

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.imshow(grayscale_mask, cmap='gray')
plt.title("Grayscale Mask")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(binary_mask, cmap='gray')
plt.title("Binary Mask (Otsu's)")
plt.axis('off')

plt.show()
# Out:
# Otsu threshold: 0.0

# %%
import cv2
import numpy as np
from pathlib import Path

def convert_to_binary_mask_otsu(grayscale_mask):
    """
    Applies Otsu's thresholding to a grayscale mask to produce a binary mask.
    """
    ret, binary_mask = cv2.threshold(grayscale_mask, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    print(f"Otsu threshold: {ret}")
    return binary_mask

def process_and_save_binary_mask(input_mask_path, output_mask_path):
    """
    Loads a grayscale mask, converts it to a binary mask using Otsu's method,
    and saves the binary mask to the output path.
    """
    # Load the grayscale mask
    grayscale_mask = cv2.imread(str(input_mask_path), cv2.IMREAD_GRAYSCALE)
    if grayscale_mask is None:
        raise FileNotFoundError(f"Could not load mask from: {input_mask_path}")
    
    # Convert the mask using Otsu's thresholding
    binary_mask = convert_to_binary_mask_otsu(grayscale_mask)
    
    # Ensure the output directory exists
    output_mask_path.parent.mkdir(parents=True, exist_ok=True)
    
    # Save the binary mask
    cv2.imwrite(str(output_mask_path), binary_mask)
    print(f"Saved binary mask to: {output_mask_path}")

def process_all_single_object_masks(input_root, output_root):
    """
    Processes all single-object mask images found under the input_root directory.
    For each sequence folder, it converts each mask image to binary and saves it in the corresponding folder under output_root.
    """
    input_root = Path(input_root)
    output_root = Path(output_root)
    
    for sequence_folder in input_root.iterdir():
        if sequence_folder.is_dir():
            # Create corresponding output folder for this sequence
            sequence_output = output_root / sequence_folder.name
            sequence_output.mkdir(parents=True, exist_ok=True)
            print(f"Processing sequence: {sequence_folder.name}")
            
            # Process each image file in the sequence folder
            for img_file in sequence_folder.iterdir():
                if img_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                    output_path = sequence_output / img_file.name
                    process_and_save_binary_mask(img_file, output_path)

if __name__ == "__main__":
    # Input directory containing your grayscale single-object masks
    input_dir = Path("output") / "grayscale_single_object_masks"
    # Output directory where the binary masks will be saved
    output_dir = Path("output") / "binary_single_object_masks"
    
    process_all_single_object_masks(input_dir, output_dir)
# Out:
# Processing sequence: hike
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00079.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00078.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00073.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00072.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00070.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00071.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00075.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00074.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00076.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00063.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/hike/00077.png
# Processing sequence: mallard-fly
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-fly/00063.png
# Processing sequence: dance-jump
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-jump/00048.png
# Processing sequence: mallard-water
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00079.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00078.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00073.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00072.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00070.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00071.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00075.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00074.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00076.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00063.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/mallard-water/00077.png
# Processing sequence: cows
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00091.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00085.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00084.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00090.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00086.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00092.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00079.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00078.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00093.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00087.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00083.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00097.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00096.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00082.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00094.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00080.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00081.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00095.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00098.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00073.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00072.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00099.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00070.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00071.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00101.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00075.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00074.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00100.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00102.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00089.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00076.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00063.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00077.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00088.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/cows/00103.png
# Processing sequence: dance-twirl
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00085.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00084.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00086.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00079.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00078.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00087.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00083.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00082.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00080.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00081.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00073.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00072.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00070.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00071.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00075.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00074.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00089.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00076.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00063.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00077.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dance-twirl/00088.png
# Processing sequence: dog
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/dog/00031.png
# ...
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/car-shadow/00028.png
# Processing sequence: blackswan
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/blackswan/00048.png
# Processing sequence: elephant
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00052.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00046.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00047.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00053.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00045.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00051.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00079.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00078.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00050.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00044.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00068.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00040.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00054.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00055.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00041.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00069.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00057.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00043.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00042.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00056.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00031.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00025.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00019.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00018.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00024.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00030.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00026.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00032.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00033.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00027.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00023.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00037.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00036.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00022.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00008.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00034.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00020.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00021.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00035.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00009.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00010.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00004.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00038.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00039.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00005.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00011.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00007.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00013.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00012.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00006.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00002.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00016.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00017.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00003.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00029.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00015.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00001.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00000.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00014.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00028.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00073.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00067.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00066.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00072.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00064.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00070.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00058.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00059.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00071.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00065.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00049.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00061.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00075.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00074.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00060.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00048.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00076.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00062.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00063.png
# Otsu threshold: 0.0
# Saved binary mask to: output/binary_single_object_masks/elephant/00077.png

# %% [markdown]
# ### STEP 3: Preprocessing the Multi-Object Video Sequences' Frames for Generating Bounding Boxes

# %% [markdown]
# #### ----NEW APPROACH---- PT 1. Deriving Bounding Boxes: Label-to-Colour

# %%
import cv2
import numpy as np
import json
from pathlib import Path

def color_mask_to_label_image(mask):
    """
    Converts a color-coded segmentation mask (BGR) into a single-channel label image.
    Each unique color (except background, assumed black) is mapped to a unique integer.
    
    Args:
        mask (np.ndarray): Color-coded mask (BGR).
        
    Returns:
        label_img (np.ndarray): Single-channel label image (dtype=uint16).
        color_to_label (dict): Mapping from each unique color (tuple) to its assigned integer label.
    """
    # Convert BGR to RGB for consistency
    mask_rgb = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    h, w, _ = mask_rgb.shape
    # Reshape to a list of pixels
    pixels = mask_rgb.reshape(-1, 3)
    unique_colors = {tuple(color) for color in np.unique(pixels, axis=0)}
    
    color_to_label = {}
    current_label = 1
    for color in unique_colors:
        if color == (0, 0, 0):  # assume background is black
            color_to_label[color] = 0
        else:
            color_to_label[color] = current_label
            current_label += 1

    label_img = np.zeros((h, w), dtype=np.uint16)
    # Iterate over all pixels (can be vectorized; for clarity we use loops)
    for y in range(h):
        for x in range(w):
            col = tuple(int(c) for c in mask_rgb[y, x])
            label_img[y, x] = color_to_label.get(col, 0)
    return label_img, color_to_label

def process_sequence_labeling(input_seq_folder, output_seq_folder, min_area=50):
    """
    Processes all color-coded segmentation mask images in an input sequence folder,
    converts each to a single-channel label image, and saves them in the output folder.
    
    Args:
        input_seq_folder (str or Path): Folder containing color-coded segmentation masks.
        output_seq_folder (str or Path): Folder where label images will be saved.
        min_area (int): (Optional) Can be used later to filter very small regions when deriving boxes.
    
    Returns:
        index_dict (dict): Dictionary mapping each processed mask filename (relative to the sequence)
                           to a dictionary with keys:
                             - "label_image": path to the saved label image
                             - "color_to_label": the mapping from colors to labels (as a dict)
    """
    input_seq_folder = Path(input_seq_folder)
    output_seq_folder = Path(output_seq_folder)
    output_seq_folder.mkdir(parents=True, exist_ok=True)
    
    index_dict = {}
    
    # Process every file in the input sequence folder
    mask_files = sorted(list(input_seq_folder.glob("*.*")))
    for mask_file in mask_files:
        # Read the color-coded segmentation mask
        mask = cv2.imread(str(mask_file), cv2.IMREAD_COLOR)
        if mask is None:
            print(f"Warning: Could not load mask {mask_file.name}")
            continue
        
        # Convert to label image and get the color-to-label mapping
        label_img, color_to_label = color_mask_to_label_image(mask)
        
        # Optionally, you might add a filtering step based on min_area here when deriving bounding boxes later.
        
        # Save the label image as a 16-bit PNG (to preserve label values)
        out_filename = mask_file.stem + "_label.png"
        out_path = output_seq_folder / out_filename
        cv2.imwrite(str(out_path), label_img)
        
        # Record the info in our index dictionary
        index_dict[mask_file.name] = {
            "label_image": str(out_path),
            "color_to_label": color_to_label  # keys will be tuples; JSON will serialize them as lists.
        }
        print(f"Processed {mask_file.name}: saved label image to {out_path}")
    
    return index_dict

def process_all_sequences(input_root, output_root, min_area=50):
    """
    Processes all multi-object segmentation sequences under the input_root folder.
    For each sequence, converts all color-coded masks to label images and saves them.
    
    Args:
        input_root (str or Path): Root folder containing sequence subfolders (e.g., "output/multi_object_annotations").
        output_root (str or Path): Root folder where label images (with same subfolder structure) will be saved.
        min_area (int): Minimum area threshold (passed to process_sequence_labeling).
    
    Returns:
        all_index (dict): Dictionary mapping sequence names to their index dictionaries.
                         Format: { "sequence_name": { "mask_filename": { "label_image": ..., "color_to_label": ... }, ... }, ... }
    """
    input_root = Path(input_root)
    output_root = Path(output_root)
    all_index = {}
    
    for seq_folder in sorted(input_root.iterdir()):
        if not seq_folder.is_dir():
            continue
        seq_name = seq_folder.name
        out_seq_folder = output_root / seq_name
        print(f"Processing sequence: {seq_name}")
        index_dict = process_sequence_labeling(seq_folder, out_seq_folder, min_area=min_area)
        all_index[seq_name] = index_dict
    
    return all_index

# -------------------------
# Main Pipeline: Process and Save Labeling for All Multi-Object Sequences
# -------------------------
if __name__ == "__main__":
    # Input root: folder containing multi-object segmentation masks (color-coded)
    input_root = Path("output/multi_object_annotations")
    # Output root: where the processed label images will be saved
    output_root = Path("output/label_images/multi_object_annotations")
    
    # Process all sequences
    all_sequences_index = process_all_sequences(input_root, output_root, min_area=50)
    
    # Save the aggregated index to a JSON file
    output_json = Path("output") / "multi_object_labeling_index.json"
    # Before dumping, convert any tuple keys (from color mappings) to lists so JSON can serialize them.
    def convert_mapping(mapping):
        return {str(k): v for k, v in mapping.items()}
    
    # We iterate over all sequences and convert the color_to_label mappings.
    for seq in all_sequences_index:
        for mask_name in all_sequences_index[seq]:
            mapping = all_sequences_index[seq][mask_name].get("color_to_label", {})
            all_sequences_index[seq][mask_name]["color_to_label"] = convert_mapping(mapping)
    
    with open(output_json, "w") as f:
        json.dump(all_sequences_index, f, indent=2)
    
    print("Saved labeling index for all multi-object sequences to:", output_json.resolve())
# Out:
# Processing sequence: bike-packing
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/bike-packing/00068_label.png
# Processing sequence: bmx-bumps
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00068_label.png
# Processed 00069.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00069_label.png
# Processed 00070.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00070_label.png
# Processed 00071.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00071_label.png
# Processed 00072.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00072_label.png
# Processed 00073.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00073_label.png
# Processed 00074.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00074_label.png
# Processed 00075.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00075_label.png
# Processed 00076.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00076_label.png
# Processed 00077.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00077_label.png
# Processed 00078.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00078_label.png
# Processed 00079.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00079_label.png
# Processed 00080.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00080_label.png
# Processed 00081.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00081_label.png
# Processed 00082.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00082_label.png
# Processed 00083.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00083_label.png
# Processed 00084.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00084_label.png
# Processed 00085.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00085_label.png
# Processed 00086.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00086_label.png
# Processed 00087.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00087_label.png
# Processed 00088.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00088_label.png
# Processed 00089.png: saved label image to output/label_images/multi_object_annotations/bmx-bumps/00089_label.png
# Processing sequence: bmx-trees
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00068_label.png
# Processed 00069.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00069_label.png
# Processed 00070.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00070_label.png
# Processed 00071.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00071_label.png
# Processed 00072.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00072_label.png
# Processed 00073.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00073_label.png
# Processed 00074.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00074_label.png
# Processed 00075.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00075_label.png
# Processed 00076.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00076_label.png
# Processed 00077.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00077_label.png
# Processed 00078.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00078_label.png
# Processed 00079.png: saved label image to output/label_images/multi_object_annotations/bmx-trees/00079_label.png
# Processing sequence: boxing-fisheye
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00068_label.png
# Processed 00069.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00069_label.png
# Processed 00070.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00070_label.png
# Processed 00071.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00071_label.png
# Processed 00072.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00072_label.png
# Processed 00073.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00073_label.png
# Processed 00074.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00074_label.png
# Processed 00075.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00075_label.png
# Processed 00076.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00076_label.png
# Processed 00077.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00077_label.png
# Processed 00078.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00078_label.png
# Processed 00079.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00079_label.png
# Processed 00080.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00080_label.png
# Processed 00081.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00081_label.png
# Processed 00082.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00082_label.png
# Processed 00083.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00083_label.png
# Processed 00084.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00084_label.png
# Processed 00085.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00085_label.png
# Processed 00086.png: saved label image to output/label_images/multi_object_annotations/boxing-fisheye/00086_label.png
# Processing sequence: cat-girl
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00068_label.png
# Processed 00069.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00069_label.png
# Processed 00070.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00070_label.png
# Processed 00071.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00071_label.png
# Processed 00072.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00072_label.png
# Processed 00073.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00073_label.png
# Processed 00074.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00074_label.png
# Processed 00075.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00075_label.png
# Processed 00076.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00076_label.png
# Processed 00077.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00077_label.png
# Processed 00078.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00078_label.png
# Processed 00079.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00079_label.png
# Processed 00080.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00080_label.png
# Processed 00081.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00081_label.png
# Processed 00082.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00082_label.png
# Processed 00083.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00083_label.png
# Processed 00084.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00084_label.png
# Processed 00085.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00085_label.png
# Processed 00086.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00086_label.png
# Processed 00087.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00087_label.png
# Processed 00088.png: saved label image to output/label_images/multi_object_annotations/cat-girl/00088_label.png
# Processing sequence: classic-car
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/classic-car/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/classic-car/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/classic-car/00002_label.png
# ...
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/tuk-tuk/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/tuk-tuk/00058_label.png
# Processing sequence: upside-down
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/upside-down/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/upside-down/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/upside-down/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/upside-down/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/upside-down/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/upside-down/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/upside-down/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/upside-down/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/upside-down/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/upside-down/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/upside-down/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/upside-down/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/upside-down/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/upside-down/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/upside-down/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/upside-down/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/upside-down/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/upside-down/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/upside-down/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/upside-down/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/upside-down/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/upside-down/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/upside-down/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/upside-down/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/upside-down/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/upside-down/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/upside-down/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/upside-down/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/upside-down/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/upside-down/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/upside-down/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/upside-down/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/upside-down/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/upside-down/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/upside-down/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/upside-down/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/upside-down/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/upside-down/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/upside-down/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/upside-down/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/upside-down/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/upside-down/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/upside-down/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/upside-down/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/upside-down/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/upside-down/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/upside-down/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/upside-down/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/upside-down/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/upside-down/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/upside-down/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/upside-down/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/upside-down/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/upside-down/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/upside-down/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/upside-down/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/upside-down/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/upside-down/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/upside-down/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/upside-down/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/upside-down/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/upside-down/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/upside-down/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/upside-down/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/upside-down/00064_label.png
# Processing sequence: walking
# Processed 00000.png: saved label image to output/label_images/multi_object_annotations/walking/00000_label.png
# Processed 00001.png: saved label image to output/label_images/multi_object_annotations/walking/00001_label.png
# Processed 00002.png: saved label image to output/label_images/multi_object_annotations/walking/00002_label.png
# Processed 00003.png: saved label image to output/label_images/multi_object_annotations/walking/00003_label.png
# Processed 00004.png: saved label image to output/label_images/multi_object_annotations/walking/00004_label.png
# Processed 00005.png: saved label image to output/label_images/multi_object_annotations/walking/00005_label.png
# Processed 00006.png: saved label image to output/label_images/multi_object_annotations/walking/00006_label.png
# Processed 00007.png: saved label image to output/label_images/multi_object_annotations/walking/00007_label.png
# Processed 00008.png: saved label image to output/label_images/multi_object_annotations/walking/00008_label.png
# Processed 00009.png: saved label image to output/label_images/multi_object_annotations/walking/00009_label.png
# Processed 00010.png: saved label image to output/label_images/multi_object_annotations/walking/00010_label.png
# Processed 00011.png: saved label image to output/label_images/multi_object_annotations/walking/00011_label.png
# Processed 00012.png: saved label image to output/label_images/multi_object_annotations/walking/00012_label.png
# Processed 00013.png: saved label image to output/label_images/multi_object_annotations/walking/00013_label.png
# Processed 00014.png: saved label image to output/label_images/multi_object_annotations/walking/00014_label.png
# Processed 00015.png: saved label image to output/label_images/multi_object_annotations/walking/00015_label.png
# Processed 00016.png: saved label image to output/label_images/multi_object_annotations/walking/00016_label.png
# Processed 00017.png: saved label image to output/label_images/multi_object_annotations/walking/00017_label.png
# Processed 00018.png: saved label image to output/label_images/multi_object_annotations/walking/00018_label.png
# Processed 00019.png: saved label image to output/label_images/multi_object_annotations/walking/00019_label.png
# Processed 00020.png: saved label image to output/label_images/multi_object_annotations/walking/00020_label.png
# Processed 00021.png: saved label image to output/label_images/multi_object_annotations/walking/00021_label.png
# Processed 00022.png: saved label image to output/label_images/multi_object_annotations/walking/00022_label.png
# Processed 00023.png: saved label image to output/label_images/multi_object_annotations/walking/00023_label.png
# Processed 00024.png: saved label image to output/label_images/multi_object_annotations/walking/00024_label.png
# Processed 00025.png: saved label image to output/label_images/multi_object_annotations/walking/00025_label.png
# Processed 00026.png: saved label image to output/label_images/multi_object_annotations/walking/00026_label.png
# Processed 00027.png: saved label image to output/label_images/multi_object_annotations/walking/00027_label.png
# Processed 00028.png: saved label image to output/label_images/multi_object_annotations/walking/00028_label.png
# Processed 00029.png: saved label image to output/label_images/multi_object_annotations/walking/00029_label.png
# Processed 00030.png: saved label image to output/label_images/multi_object_annotations/walking/00030_label.png
# Processed 00031.png: saved label image to output/label_images/multi_object_annotations/walking/00031_label.png
# Processed 00032.png: saved label image to output/label_images/multi_object_annotations/walking/00032_label.png
# Processed 00033.png: saved label image to output/label_images/multi_object_annotations/walking/00033_label.png
# Processed 00034.png: saved label image to output/label_images/multi_object_annotations/walking/00034_label.png
# Processed 00035.png: saved label image to output/label_images/multi_object_annotations/walking/00035_label.png
# Processed 00036.png: saved label image to output/label_images/multi_object_annotations/walking/00036_label.png
# Processed 00037.png: saved label image to output/label_images/multi_object_annotations/walking/00037_label.png
# Processed 00038.png: saved label image to output/label_images/multi_object_annotations/walking/00038_label.png
# Processed 00039.png: saved label image to output/label_images/multi_object_annotations/walking/00039_label.png
# Processed 00040.png: saved label image to output/label_images/multi_object_annotations/walking/00040_label.png
# Processed 00041.png: saved label image to output/label_images/multi_object_annotations/walking/00041_label.png
# Processed 00042.png: saved label image to output/label_images/multi_object_annotations/walking/00042_label.png
# Processed 00043.png: saved label image to output/label_images/multi_object_annotations/walking/00043_label.png
# Processed 00044.png: saved label image to output/label_images/multi_object_annotations/walking/00044_label.png
# Processed 00045.png: saved label image to output/label_images/multi_object_annotations/walking/00045_label.png
# Processed 00046.png: saved label image to output/label_images/multi_object_annotations/walking/00046_label.png
# Processed 00047.png: saved label image to output/label_images/multi_object_annotations/walking/00047_label.png
# Processed 00048.png: saved label image to output/label_images/multi_object_annotations/walking/00048_label.png
# Processed 00049.png: saved label image to output/label_images/multi_object_annotations/walking/00049_label.png
# Processed 00050.png: saved label image to output/label_images/multi_object_annotations/walking/00050_label.png
# Processed 00051.png: saved label image to output/label_images/multi_object_annotations/walking/00051_label.png
# Processed 00052.png: saved label image to output/label_images/multi_object_annotations/walking/00052_label.png
# Processed 00053.png: saved label image to output/label_images/multi_object_annotations/walking/00053_label.png
# Processed 00054.png: saved label image to output/label_images/multi_object_annotations/walking/00054_label.png
# Processed 00055.png: saved label image to output/label_images/multi_object_annotations/walking/00055_label.png
# Processed 00056.png: saved label image to output/label_images/multi_object_annotations/walking/00056_label.png
# Processed 00057.png: saved label image to output/label_images/multi_object_annotations/walking/00057_label.png
# Processed 00058.png: saved label image to output/label_images/multi_object_annotations/walking/00058_label.png
# Processed 00059.png: saved label image to output/label_images/multi_object_annotations/walking/00059_label.png
# Processed 00060.png: saved label image to output/label_images/multi_object_annotations/walking/00060_label.png
# Processed 00061.png: saved label image to output/label_images/multi_object_annotations/walking/00061_label.png
# Processed 00062.png: saved label image to output/label_images/multi_object_annotations/walking/00062_label.png
# Processed 00063.png: saved label image to output/label_images/multi_object_annotations/walking/00063_label.png
# Processed 00064.png: saved label image to output/label_images/multi_object_annotations/walking/00064_label.png
# Processed 00065.png: saved label image to output/label_images/multi_object_annotations/walking/00065_label.png
# Processed 00066.png: saved label image to output/label_images/multi_object_annotations/walking/00066_label.png
# Processed 00067.png: saved label image to output/label_images/multi_object_annotations/walking/00067_label.png
# Processed 00068.png: saved label image to output/label_images/multi_object_annotations/walking/00068_label.png
# Processed 00069.png: saved label image to output/label_images/multi_object_annotations/walking/00069_label.png
# Processed 00070.png: saved label image to output/label_images/multi_object_annotations/walking/00070_label.png
# Processed 00071.png: saved label image to output/label_images/multi_object_annotations/walking/00071_label.png
# Saved labeling index for all multi-object sequences to: /Users/dd/PycharmProjects/CV-ObjectDetection_ImageSegmentation/output/multi_object_labeling_index.json
