# %% [markdown]
# #### PT.3 Deriving Bounding Boxes: Utilization of Binary Single-Object Masks

# %%
import cv2
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

def derive_bounding_boxes(binary_mask):
    """
    Derives bounding boxes from a binary mask using connected components.
    Assumes that 0 is background and non-zero (255) is the object.
    Returns a list of bounding boxes (x, y, w, h).
    """
    # Ensure binary_mask is of type uint8
    binary_mask = binary_mask.astype(np.uint8)
    
    # Use connected components to get all regions
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)
    
    bounding_boxes = []
    # Skip the background (label 0)
    for i in range(1, num_labels):
        x, y, w, h, area = stats[i]
        # Optionally, filter out very small areas if needed
        if area > 50:
            bounding_boxes.append((x, y, w, h))
    return bounding_boxes

def process_and_visualize_bounding_boxes(input_dir):
    """
    Processes all binary masks in the given input directory, derives bounding boxes,
    and visualizes them on the corresponding raw frame if available.
    """
    input_dir = Path(input_dir)
    
    # Iterate over each sequence folder (each representing a video sequence)
    for sequence_folder in input_dir.iterdir():
        if sequence_folder.is_dir():
            print(f"Processing sequence: {sequence_folder.name}")
            # For demonstration, process the first image mask in the sequence folder.
            mask_files = sorted([f for f in sequence_folder.iterdir() if f.suffix.lower() in ['.png', '.jpg', '.jpeg']])
            if mask_files:
                sample_mask_path = mask_files[0]
                binary_mask = cv2.imread(str(sample_mask_path), cv2.IMREAD_GRAYSCALE)
                boxes = derive_bounding_boxes(binary_mask)
                print(f"Bounding boxes for {sample_mask_path.name}: {boxes}")
                
                # Optionally visualize the bounding boxes on the mask itself
                mask_with_boxes = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
                for (x, y, w, h) in boxes:
                    cv2.rectangle(mask_with_boxes, (x, y), (x+w, y+h), (0, 255, 0), 2)
                
                # Display the image with bounding boxes using matplotlib
                plt.figure(figsize=(6, 6))
                plt.imshow(cv2.cvtColor(mask_with_boxes, cv2.COLOR_BGR2RGB))
                plt.title(f"Bounding Boxes in {sequence_folder.name}")
                plt.axis('off')
                plt.show()
            else:
                print(f"No mask files found in {sequence_folder}")

if __name__ == "__main__":
    # Input directory with binary masks (from your previous processing)
    binary_masks_dir = Path("output") / "binary_single_object_masks"
    process_and_visualize_bounding_boxes(binary_masks_dir)
# Out:
# Processing sequence: hike
# Bounding boxes for 00000.png: [(np.int32(413), np.int32(140), np.int32(165), np.int32(289))]
# Processing sequence: mallard-fly
# Bounding boxes for 00000.png: [(np.int32(239), np.int32(226), np.int32(179), np.int32(146)), (np.int32(307), np.int32(348), np.int32(10), np.int32(11))]
# Processing sequence: dance-jump
# Bounding boxes for 00000.png: [(np.int32(285), np.int32(54), np.int32(291), np.int32(314))]
# Processing sequence: mallard-water
# Bounding boxes for 00000.png: [(np.int32(274), np.int32(125), np.int32(336), np.int32(143))]
# Processing sequence: cows
# Bounding boxes for 00000.png: [(np.int32(217), np.int32(125), np.int32(405), np.int32(271))]
# Processing sequence: dance-twirl
# Bounding boxes for 00000.png: [(np.int32(335), np.int32(59), np.int32(170), np.int32(372))]
# Processing sequence: dog
# Bounding boxes for 00000.png: [(np.int32(151), np.int32(11), np.int32(361), np.int32(294))]
# Processing sequence: lucia
# Bounding boxes for 00000.png: [(np.int32(275), np.int32(84), np.int32(102), np.int32(298)), (np.int32(299), np.int32(357), np.int32(11), np.int32(29)), (np.int32(296), np.int32(389), np.int32(5), np.int32(22)), (np.int32(302), np.int32(390), np.int32(4), np.int32(23)), (np.int32(289), np.int32(411), np.int32(35), np.int32(21))]
# Processing sequence: bear
# Bounding boxes for 00001.png: [(np.int32(95), np.int32(215), np.int32(366), np.int32(220))]
# Processing sequence: boat
# Bounding boxes for 00000.png: [(np.int32(265), np.int32(158), np.int32(433), np.int32(155))]
# Processing sequence: rollerblade
# Bounding boxes for 00000.png: [(np.int32(94), np.int32(89), np.int32(101), np.int32(293))]
# Processing sequence: camel
# Bounding boxes for 00000.png: [(np.int32(261), np.int32(85), np.int32(448), np.int32(345))]
# Processing sequence: drift-chicane
# Bounding boxes for 00000.png: [(np.int32(144), np.int32(216), np.int32(83), np.int32(45))]
# Processing sequence: parkour
# Bounding boxes for 00000.png: [(np.int32(509), np.int32(54), np.int32(91), np.int32(168))]
# Processing sequence: bus
# Bounding boxes for 00000.png: [(np.int32(121), np.int32(63), np.int32(474), np.int32(256)), (np.int32(272), np.int32(195), np.int32(11), np.int32(57))]
# Processing sequence: goat
# Bounding boxes for 00000.png: [(np.int32(349), np.int32(71), np.int32(217), np.int32(319))]
# Processing sequence: breakdance
# Bounding boxes for 00000.png: [(np.int32(225), np.int32(4), np.int32(199), np.int32(447))]
# Processing sequence: car-roundabout
# Bounding boxes for 00000.png: [(np.int32(250), np.int32(177), np.int32(440), np.int32(181))]
# Processing sequence: soccerball
# Bounding boxes for 00000.png: [(np.int32(710), np.int32(301), np.int32(125), np.int32(106))]
# Processing sequence: drift-turn
# Bounding boxes for 00000.png: [(np.int32(218), np.int32(173), np.int32(135), np.int32(80))]
# Processing sequence: breakdance-flare
# Bounding boxes for 00000.png: [(np.int32(201), np.int32(12), np.int32(356), np.int32(389))]
# Processing sequence: dog-agility
# Bounding boxes for 00000.png: [(np.int32(420), np.int32(200), np.int32(86), np.int32(174)), (np.int32(521), np.int32(215), np.int32(294), np.int32(192)), (np.int32(335), np.int32(365), np.int32(67), np.int32(47))]
# Processing sequence: libby
# Bounding boxes for 00000.png: [(np.int32(292), np.int32(171), np.int32(134), np.int32(152)), (np.int32(440), np.int32(192), np.int32(128), np.int32(156))]
# Processing sequence: drift-straight
# Bounding boxes for 00000.png: [(np.int32(590), np.int32(200), np.int32(99), np.int32(61))]
# Processing sequence: rhino
# Bounding boxes for 00000.png: [(np.int32(138), np.int32(148), np.int32(493), np.int32(266))]
# Processing sequence: koala
# Bounding boxes for 00000.png: [(np.int32(0), np.int32(32), np.int32(854), np.int32(448))]
# Processing sequence: rallye
# Bounding boxes for 00000.png: [(np.int32(247), np.int32(253), np.int32(38), np.int32(27))]
# Processing sequence: varanus-cage
# Bounding boxes for 00000.png: [(np.int32(282), np.int32(46), np.int32(275), np.int32(130)), (np.int32(507), np.int32(194), np.int32(32), np.int32(232))]
# Processing sequence: flamingo
# Bounding boxes for 00000.png: [(np.int32(340), np.int32(118), np.int32(351), np.int32(288))]
# Processing sequence: car-turn
# Bounding boxes for 00000.png: [(np.int32(700), np.int32(212), np.int32(101), np.int32(93))]
# Processing sequence: car-shadow
# Bounding boxes for 00000.png: [(np.int32(313), np.int32(88), np.int32(342), np.int32(194))]
# Processing sequence: blackswan
# Bounding boxes for 00000.png: [(np.int32(127), np.int32(73), np.int32(383), np.int32(312))]
# Processing sequence: elephant
# Bounding boxes for 00000.png: [(np.int32(254), np.int32(88), np.int32(293), np.int32(329)), (np.int32(547), np.int32(208), np.int32(11), np.int32(68))]

# %%
import cv2
import numpy as np
import json
from pathlib import Path

def derive_bounding_boxes(binary_mask, min_area=50):
    """
    Derives bounding boxes from a binary mask using connected components.
    Assumes that 0 is background and non-zero (255) is the object.
    Returns a list of bounding boxes, each as (x, y, w, h).
    """
    # Ensure the binary mask is of type uint8.
    binary_mask = binary_mask.astype(np.uint8)
    
    # Use connected components to get all regions in the binary mask.
    num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)
    
    boxes = []
    # Skip the background label (0).
    for i in range(1, num_labels):
        x, y, w, h, area = stats[i]
        if area > min_area:  # filter out small regions if needed
            boxes.append((int(x), int(y), int(w), int(h)))
    return boxes

def save_bounding_boxes_for_sequence(seq_input_folder, seq_output_folder):
    """
    Processes all binary mask images in a sequence folder,
    derives bounding boxes for each image, and saves them in a JSON file.
    """
    # Ensure the output folder for this sequence exists.
    seq_output_folder.mkdir(parents=True, exist_ok=True)
    
    bb_data = {}  # dictionary to hold bounding boxes for each mask file
    
    # Process each mask image in the sequence folder.
    for mask_file in sorted(seq_input_folder.glob("*.*")):
        if mask_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
            mask = cv2.imread(str(mask_file), cv2.IMREAD_GRAYSCALE)
            if mask is None:
                print(f"Could not load {mask_file}")
                continue
            boxes = derive_bounding_boxes(mask)
            bb_data[mask_file.name] = boxes
    
    # Save the bounding boxes dictionary as a JSON file in the sequence output folder.
    output_json_path = seq_output_folder / "bounding_boxes.json"
    with open(output_json_path, "w") as f:
        json.dump(bb_data, f, indent=2)
    print(f"Saved bounding boxes for sequence '{seq_input_folder.name}' to {output_json_path}")

def process_all_sequences(input_root, output_root):
    """
    Iterates over all sequence folders in the input_root directory,
    derives bounding boxes for each binary mask image, and saves the results.
    """
    input_root = Path(input_root)
    output_root = Path(output_root)
    
    for seq_folder in input_root.iterdir():
        if seq_folder.is_dir():
            seq_output_folder = output_root / seq_folder.name
            print(f"Processing sequence: {seq_folder.name}")
            save_bounding_boxes_for_sequence(seq_folder, seq_output_folder)

if __name__ == "__main__":
    # Input directory with your binary masks for single-object sequences.
    binary_masks_root = Path("output") / "binary_single_object_masks"
    # Output directory for the bounding boxes (adjusted as requested).
    bounding_boxes_output_root = Path("output") / "bounding_boxes-single_object"
    
    process_all_sequences(binary_masks_root, bounding_boxes_output_root)
# Out:
# Processing sequence: hike
# Saved bounding boxes for sequence 'hike' to output/bounding_boxes-single_object/hike/bounding_boxes.json
# Processing sequence: mallard-fly
# Saved bounding boxes for sequence 'mallard-fly' to output/bounding_boxes-single_object/mallard-fly/bounding_boxes.json
# Processing sequence: dance-jump
# Saved bounding boxes for sequence 'dance-jump' to output/bounding_boxes-single_object/dance-jump/bounding_boxes.json
# Processing sequence: mallard-water
# Saved bounding boxes for sequence 'mallard-water' to output/bounding_boxes-single_object/mallard-water/bounding_boxes.json
# Processing sequence: cows
# Saved bounding boxes for sequence 'cows' to output/bounding_boxes-single_object/cows/bounding_boxes.json
# Processing sequence: dance-twirl
# Saved bounding boxes for sequence 'dance-twirl' to output/bounding_boxes-single_object/dance-twirl/bounding_boxes.json
# Processing sequence: dog
# Saved bounding boxes for sequence 'dog' to output/bounding_boxes-single_object/dog/bounding_boxes.json
# Processing sequence: lucia
# Saved bounding boxes for sequence 'lucia' to output/bounding_boxes-single_object/lucia/bounding_boxes.json
# Processing sequence: bear
# Saved bounding boxes for sequence 'bear' to output/bounding_boxes-single_object/bear/bounding_boxes.json
# Processing sequence: boat
# Saved bounding boxes for sequence 'boat' to output/bounding_boxes-single_object/boat/bounding_boxes.json
# Processing sequence: rollerblade
# Saved bounding boxes for sequence 'rollerblade' to output/bounding_boxes-single_object/rollerblade/bounding_boxes.json
# Processing sequence: camel
# Saved bounding boxes for sequence 'camel' to output/bounding_boxes-single_object/camel/bounding_boxes.json
# Processing sequence: drift-chicane
# Saved bounding boxes for sequence 'drift-chicane' to output/bounding_boxes-single_object/drift-chicane/bounding_boxes.json
# Processing sequence: parkour
# Saved bounding boxes for sequence 'parkour' to output/bounding_boxes-single_object/parkour/bounding_boxes.json
# Processing sequence: bus
# Saved bounding boxes for sequence 'bus' to output/bounding_boxes-single_object/bus/bounding_boxes.json
# Processing sequence: goat
# Saved bounding boxes for sequence 'goat' to output/bounding_boxes-single_object/goat/bounding_boxes.json
# Processing sequence: breakdance
# Saved bounding boxes for sequence 'breakdance' to output/bounding_boxes-single_object/breakdance/bounding_boxes.json
# Processing sequence: car-roundabout
# Saved bounding boxes for sequence 'car-roundabout' to output/bounding_boxes-single_object/car-roundabout/bounding_boxes.json
# Processing sequence: soccerball
# Saved bounding boxes for sequence 'soccerball' to output/bounding_boxes-single_object/soccerball/bounding_boxes.json
# Processing sequence: drift-turn
# Saved bounding boxes for sequence 'drift-turn' to output/bounding_boxes-single_object/drift-turn/bounding_boxes.json
# Processing sequence: breakdance-flare
# Saved bounding boxes for sequence 'breakdance-flare' to output/bounding_boxes-single_object/breakdance-flare/bounding_boxes.json
# Processing sequence: dog-agility
# Saved bounding boxes for sequence 'dog-agility' to output/bounding_boxes-single_object/dog-agility/bounding_boxes.json
# Processing sequence: libby
# Saved bounding boxes for sequence 'libby' to output/bounding_boxes-single_object/libby/bounding_boxes.json
# Processing sequence: drift-straight
# Saved bounding boxes for sequence 'drift-straight' to output/bounding_boxes-single_object/drift-straight/bounding_boxes.json
# Processing sequence: rhino
# Saved bounding boxes for sequence 'rhino' to output/bounding_boxes-single_object/rhino/bounding_boxes.json
# Processing sequence: koala
# Saved bounding boxes for sequence 'koala' to output/bounding_boxes-single_object/koala/bounding_boxes.json
# Processing sequence: rallye
# Saved bounding boxes for sequence 'rallye' to output/bounding_boxes-single_object/rallye/bounding_boxes.json
# Processing sequence: varanus-cage
# Saved bounding boxes for sequence 'varanus-cage' to output/bounding_boxes-single_object/varanus-cage/bounding_boxes.json
# Processing sequence: flamingo
# Saved bounding boxes for sequence 'flamingo' to output/bounding_boxes-single_object/flamingo/bounding_boxes.json
# Processing sequence: car-turn
# Saved bounding boxes for sequence 'car-turn' to output/bounding_boxes-single_object/car-turn/bounding_boxes.json
# Processing sequence: car-shadow
# Saved bounding boxes for sequence 'car-shadow' to output/bounding_boxes-single_object/car-shadow/bounding_boxes.json
# Processing sequence: blackswan
# Saved bounding boxes for sequence 'blackswan' to output/bounding_boxes-single_object/blackswan/bounding_boxes.json
# Processing sequence: elephant
# Saved bounding boxes for sequence 'elephant' to output/bounding_boxes-single_object/elephant/bounding_boxes.json
